# %%
import pandas as pd

df = pd.read_csv("../../1_databases/1_data_extraction/data/assets_info.csv")

df = df.sort_values(by="growth_score", ascending=False)

df.head(10)
# Out:
#      ticker                       asset_name                  sector exchange  \
# 42   HSBA.L  HSBC HOLDINGS PLC ORD $0.50 (UK      Financial Services      LSE
# 43  2330.TW  TAIWAN SEMICONDUCTOR MANUFACTUR              Technology      TAI
# 24     MSFT            Microsoft Corporation              Technology      NMS
# 23     AAPL                       Apple Inc.              Technology      NMS
# 30     TSLA                      Tesla, Inc.       Consumer Cyclical      NMS
# 35   IBE.MC               ACCIONES IBERDROLA               Utilities      MCE
# 25     AMZN                 Amazon.com, Inc.       Consumer Cyclical      NMS
# 38  ASML.AS                     ASML HOLDING              Technology      AMS
# 27      JPM            JP Morgan Chase & Co.      Financial Services      NYQ
# 46    TCEHY             Tencent Holding Ltd.  Communication Services      PNK
#
#    currency   beta  dividend_yield  trailingpe  pricetobook  fcf_yield  \
# 42      GBp  0.555            4.12   15.256180     1.773990        NaN
# 43      TWD  1.251            1.12   28.984522     9.398456   0.013033
# 24      USD  1.107            0.89   24.688429     7.883029   0.012013
# 23      USD    NaN            0.38   35.896202    47.279090   0.024135
# 30      USD  1.915             NaN  354.396300    17.965015   0.003555
# 35      EUR  0.604            3.28   24.937500     2.628458  -0.012752
# 25      USD  1.383             NaN   32.297005     7.040150   0.008204
# 38      EUR  1.382            0.88   47.178696    22.617770   0.017497
# 27      USD  1.043            1.92   15.041168     2.447500        NaN
# 46      USD  0.800            1.11   17.314447     3.260614   0.252172
#
#     revenuegrowth  earningsgrowth  forwardeps  payoutratio asset_type  \
# 42          0.584          23.979    1.351349       0.5345     Equity
# 43          0.351           0.584  120.766290       0.2785     Equity
# 24          0.183           0.234   19.297790       0.2073     Equity
# 23          0.166           0.218    9.396790       0.1304     Equity
# 30          0.158           0.083    2.535360       0.0000     Equity
# 35          0.005           5.598    1.051790       0.7592     Equity
# 25          0.136           0.050    9.825060       0.0000     Equity
# 38          0.132           0.192   40.763970       0.2568     Equity
# 27          0.127           0.172   23.510630       0.2824     Equity
# 46          0.127           0.141    5.024707       0.1708     Equity
#
#     value_score  growth_score  dividend_score
# 42          NaN      8.666931             NaN
# 43    -2.081887      1.852709        0.010532
# 24    -1.937930      0.451874        0.008475
# 23    -2.652472      0.314252        0.007975
# 30          NaN      0.222383             NaN
# 35    -0.981951      0.187087       -0.010072
# 25          NaN      0.041669             NaN
# 38    -2.798879      0.040282        0.011443
# 27          NaN     -0.003447             NaN
# 46     3.013395     -0.010039        0.232102
