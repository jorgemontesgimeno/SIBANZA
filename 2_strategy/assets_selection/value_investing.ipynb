# %%
import pandas as pd

df = pd.read_csv("../../1_databases/1_data_extraction/data/assets_info.csv")

df = df.sort_values(by="value_score", ascending=False)

df.head(10)
# Out:
#      ticker                       asset_name                  sector exchange  \
# 48     VALE                        VALE S.A.         Basic Materials      NYQ
# 46    TCEHY             Tencent Holding Ltd.  Communication Services      PNK
# 44   7203.T                TOYOTA MOTOR CORP       Consumer Cyclical      JPX
# 49      BHP                BHP Group Limited         Basic Materials      NYQ
# 40  NESN.SW                         NESTLE N      Consumer Defensive      EBS
# 36    MC.PA                             LVMH       Consumer Cyclical      PAR
# 29       PG   Procter & Gamble Company (The)      Consumer Defensive      NYQ
# 31      UNH  UnitedHealth Group Incorporated              Healthcare      NYQ
# 28      XOM          Exxon Mobil Corporation                  Energy      NYQ
# 37   SAP.DE  SAP SE                        I              Technology      GER
#
#    currency   beta  dividend_yield  trailingpe  pricetobook  fcf_yield  \
# 48      USD  0.889            7.69   24.401514     1.866097   0.154340
# 46      USD  0.800            1.11   17.314447     3.260614   0.252172
# 44      JPY  0.357            3.14   10.557432     1.003219  -0.001468
# 49      USD  0.798            3.35   19.610420     3.979756   0.040531
# 40      CHF  0.516            3.92   22.521368     6.197570   0.030680
# 36      EUR  0.895            2.88   20.659039     3.320949   0.052427
# 29      USD  0.403            2.90   21.691519     6.428231   0.036857
# 31      USD  0.408            2.39   27.916100     3.555557   0.052731
# 28      USD  0.288            2.67   22.837313     2.465160   0.019229
# 37      EUR  0.762            1.72   23.317308     3.810197   0.047938
#
#     revenuegrowth  earningsgrowth  forwardeps  payoutratio asset_type  \
# 48          0.027           0.220    2.136670       1.2050     Equity
# 46          0.127           0.141    5.024707       0.1708     Equity
# 44          0.086          -0.423  324.220000       0.3343     Equity
# 49          0.108           0.275    5.233210       0.5464     Equity
# 40         -0.022          -0.240    4.688440       0.8689     Equity
# 36         -0.047          -0.014   25.946150       0.5950     Equity
# 29          0.074           0.058    7.113090       0.6180     Equity
# 31          0.020           0.007   20.753670       0.6599     Equity
# 28         -0.013          -0.110   10.167900       0.5970     Equity
# 37          0.060           0.093    8.547760       0.3766     Equity
#
#     value_score  growth_score  dividend_score
# 48     4.384751     -0.782771       -0.243309
# 46     3.013395     -0.010039        0.232102
# 44     1.801929     -0.453673       -0.003068
# 49     0.473949     -0.131556        0.061589
# 40     0.317758     -1.267454        0.015767
# 36     0.272225     -1.416781        0.061150
# 29    -0.087714     -0.446139        0.040830
# 31    -0.622930     -0.883330        0.042862
# 28    -0.624865     -1.168754        0.020691
# 37    -0.744607     -0.549231        0.051402
