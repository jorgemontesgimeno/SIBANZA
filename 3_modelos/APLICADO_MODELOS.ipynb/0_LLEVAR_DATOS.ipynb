# %%
import pandas as pd

df_assets = pd.read_csv("../../1_databases/1_data_extraction/data/historical_assets.csv")

for ticker, df in df_assets.groupby("ticker"):
    df.to_csv(f"data/{ticker}.csv", index=False)
